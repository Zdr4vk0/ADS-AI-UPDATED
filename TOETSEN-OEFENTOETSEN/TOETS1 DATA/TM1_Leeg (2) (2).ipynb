# %%
import pandas as pd
import numpy as np

pokedex = pd.read_csv('pokemon.csv')
columns = list(pokedex.columns)
data= pokedex
pd.DataFrame({'columns':columns})

pokedex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %%
pokedex.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
#1a:
data = pokedex
selectie = data[(data['type1'] == 'water') & (data['type2'] == 'flying')]
mean = selectie['attack'].mean().round(3)
print(mean)
print(f' Het gemiddelde attack stat van Water/Flying pokemon is: {mean}')
# Out:
# 60.857
#  Het gemiddelde attack stat van Water/Flying pokemon is: 60.857

# %%
#2a:
pd.set_option('display.max_columns', None)
selectie1 = (data[(data['type1'] =='dragon')|(data['type2'] == 'dragon')])
pvt = selectie.pivot_table(index=['generation'], values=['attack', 'defense','speed', 'hp', 'sp_attack','sp_attack' ]
                           , aggfunc=['sum', 'mean'])
display(pvt)
# Out:
#               sum                                               mean  \
#            attack defense   hp sp_attack sp_attack speed      attack
# generation
# 1             282     205  193       220       220   200   94.000000
# 2              95      95   75        95        95    85   95.000000
# 3            1005     850  675       940       940   805  111.666667
# 4             690     545  574       630       630   496  115.000000
# 5            1116     830  806       865       865   738  111.600000
# 6             710     680  749       692       692   606   78.888889
# 7             479     553  536       533       533   310   79.833333
#
#
#               defense         hp   sp_attack   sp_attack      speed
# generation
# 1           68.333333  64.333333   73.333333   73.333333  66.666667
# 2           95.000000  75.000000   95.000000   95.000000  85.000000
# 3           94.444444  75.000000  104.444444  104.444444  89.444444
# ...

# %%
#2b:
#Geef in een comment je antwoord aan.

#Omdat er in gen2 waarschijnlijk de minste aantal pokemons zitten met 'dragon' als type1 of type2
#, maar deze hebben wel gemiddeld een hoger sp_defense dan de rest. Daarom is de opsomming het kleinst, maar de mean het grootst

# %%
#3a:
selectie = data[data['type1'] == 'fire']
pvt2 = selectie.pivot_table(index=['generation','classification', 'is_legendary'],values=['capture_rate'], aggfunc='mean')
display(pvt2)
# Out:
#                                                capture_rate
# generation classification        is_legendary
# 1          Fire Horse Pokémon    0                    125.0
#            Flame Pokémon         0                     45.0
#                                  1                      3.0
#            Fox Pokémon           0                    132.5
#            Legendary Pokémon     0                     75.0
#            Lizard Pokémon        0                     45.0
#            Puppy Pokémon         0                    190.0
#            Spitfire Pokémon      0                     45.0
# 2          Fire Mouse Pokémon    0                     45.0
#            Lava Pokémon          0                    132.5
#            Live Coal Pokémon     0                     45.0
#            Rainbow Pokémon       1                      3.0
#            Volcano Pokémon       0                     45.0
#                                  1                      3.0
# ...

# %%
#4a:
selectie = data[data['type1'] == 'steel']
pvt = selectie.pivot_table(index=['generation'],columns=['type1'], values=['weight_kg'], aggfunc='mean')
#nu een change kolom maken die de pct_change() berekent per generation
pvt['change'] = pvt.pct_change()
display(pvt2)
max1 = pvt2['change'].max() #dit is de meeste procentuele change(in dit geval 33.5728)
maxgen = pvt2['change'].idxmax() #dit is de bijbehorende generatie(in dit geval gen7)
print(f'De grootste procentuele verrandering was in gen {maxgen}, hier was de procentuele verrandering {(max1)}%')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       4 #nu een change kolom maken die de pct_change() berekent per generation
#       5 pvt['change'] = pvt.pct_change()
# ----> 6 display(pvt2)
#       7 max1 = pvt2['change'].max() #dit is de meeste procentuele change(in dit geval 33.5728)
#       8 maxgen = pvt2['change'].idxmax() #dit is de bijbehorende generatie(in dit geval gen7)
#
# NameError: name 'pvt2' is not defined
